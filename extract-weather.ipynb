# %%
# !pip install pandas sqlalchemy psycopg2-binary javaobj-py3

# %%
import os
import logging
import pandas as pd
from sqlalchemy import create_engine, text
import javaobj  # из пакета javaobj-py3

logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)


DB_URI = "postgresql://postgres:smartgrid@172.31.168.2/solar_db"  
engine = create_engine(DB_URI)


OUTPUT_DIR = "data"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def extract_weather_from_db(user_object_id, prediction_date):
    """
    1) Извличане на current_data от weather_data
    2) Десериализация на Java обект
    3) Извличане на forecast → extract_forecast_data
    4) DataFrame + конвертиране на time в datetime
    5) Числови колони
    6) Ресемплиране на 15-минутен интервал + интерполация
    """
    sql = text("""
        SELECT current_data
        FROM weather_data
        WHERE user_object_id = :uid
          AND date = :dt
        ORDER BY id
        LIMIT 1
    """)

    with engine.connect() as conn:
        row = conn.execute(sql, {"uid": user_object_id, "dt": prediction_date}).fetchone()

    if not row:
        logger.error("Няма записи за user_object_id=%s на %s", user_object_id, prediction_date)
        return None

    root_obj = deserialize_java_object(row[0])
    if root_obj is None:
        return None

    forecast_obj = getattr(root_obj, "forecast", None)
    if forecast_obj is None:
        logger.error("В десериализирания обект няма атрибут forecast")
        return None

    raw = extract_forecast_data(forecast_obj)
    if not raw:
        logger.error("extract_forecast_data върна празен списък")
        return None

    df = pd.DataFrame(raw)

    # конвертиране на време и индексиране
    try:
        df["time"] = pd.to_datetime(df["time"], format="%Y-%m-%d %H:%M")
    except Exception as e:
        logger.error("Неуспешна конверсия на време: %s", e)
        return None

    df = df.drop_duplicates(subset="time").set_index("time").sort_index()

    # числови колони
    for col in ["temp_c", "cloud"]:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    # проверка дали има какво да се интерполира
    if df[["temp_c", "cloud"]].isna().all().all():
        logger.error("Няма валидни числа в temp_c или cloud за интерполация")
        return None

    # ресемплиране + интерполация
    try:
        df15 = df.resample("15min").interpolate(method="linear")
    except Exception as e:
        logger.error("Грешка при ресемплиране: %s", e)
        return None

    # финална подготовка
    df15 = df15.reset_index()             # <-- вот тут была ошибка
    df15["time"] = df15["time"].dt.strftime("%Y-%m-%d %H:%M")
    return df15

# %%
# Параметры нашего объекта и даты прогноза
user_object_id = 70          # здесь ставишь ID нужного объекта
prediction_date = "2025-03-20"  # дата в формате YYYY-MM-DD

df_weather = extract_weather_from_db(user_object_id, prediction_date)

if df_weather is None:
    print("Не удалось получить данные погоды.")
else:
    display(df_weather.head())

    # имя файла: база_данных/weather_uid_70_2025-03-20.csv
    filename = f"weather_uid_{user_object_id}_{prediction_date}.csv"
    out_path = os.path.join(OUTPUT_DIR, filename)

    df_weather.to_csv(out_path, index=False, encoding="utf-8")
    print("Успешно записано в:", out_path)

# %%
# --- Итеративная выгрузка погоды с 15.08.2024 по 25.02.2025 ---

user_object_id = 70
start_date = "2024-08-15"
end_date   = "2025-02-25"

date_range = pd.date_range(start=start_date, end=end_date, freq="D")

# Папка для сохранения
OUTPUT_DIR = "data"
os.makedirs(OUTPUT_DIR, exist_ok=True)

for dt in date_range:
    prediction_date = dt.strftime("%Y-%m-%d")
    print(f"Обрабатываем {prediction_date} ...")

    df_weather = extract_weather_from_db(user_object_id, prediction_date)

    if df_weather is None or df_weather.empty:
        print(f"  ⚠ Нет данных погоды для {prediction_date}")
        continue

    # Формируем имя файла
    filename = f"weather_uid_{user_object_id}_{prediction_date}.csv"
    out_path = os.path.join(OUTPUT_DIR, filename)

    # Сохраняем
    df_weather.to_csv(out_path, index=False, encoding="utf-8")
    print(f"  ✅ Успешно записано: {out_path}")

print("Готово!")
# Out:
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-15
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-16
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-17
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-18
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-19
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-20
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-21
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-22
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-23
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-24
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-25
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-26
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-27
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-28
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-29
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-30
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-08-31
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-01
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-02
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-03
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-04
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-05
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-06
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-07
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-08
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-09
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-10
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-11
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-12
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-13
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-14
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-15
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-16
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-17
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-18
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-19
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-20
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-21
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-22
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-23
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-24
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-25
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-26
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-27
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-28
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-29
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-09-30
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-01
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-02
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-03
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-04
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-05
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-06
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-07
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-08
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-09
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-10
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-11
# Обрабатываем 2024-08-15 ...
#   ⚠ Нет данных погоды для 2024-08-15
# Обрабатываем 2024-08-16 ...
#   ⚠ Нет данных погоды для 2024-08-16
# Обрабатываем 2024-08-17 ...
#   ⚠ Нет данных погоды для 2024-08-17
# Обрабатываем 2024-08-18 ...
#   ⚠ Нет данных погоды для 2024-08-18
# Обрабатываем 2024-08-19 ...
#   ⚠ Нет данных погоды для 2024-08-19
# Обрабатываем 2024-08-20 ...
#   ⚠ Нет данных погоды для 2024-08-20
# Обрабатываем 2024-08-21 ...
#   ⚠ Нет данных погоды для 2024-08-21
# Обрабатываем 2024-08-22 ...
#   ⚠ Нет данных погоды для 2024-08-22
# Обрабатываем 2024-08-23 ...
#   ⚠ Нет данных погоды для 2024-08-23
# Обрабатываем 2024-08-24 ...
#   ⚠ Нет данных погоды для 2024-08-24
# Обрабатываем 2024-08-25 ...
#   ⚠ Нет данных погоды для 2024-08-25
# Обрабатываем 2024-08-26 ...
#   ⚠ Нет данных погоды для 2024-08-26
# Обрабатываем 2024-08-27 ...
#   ⚠ Нет данных погоды для 2024-08-27
# Обрабатываем 2024-08-28 ...
#   ⚠ Нет данных погоды для 2024-08-28
# Обрабатываем 2024-08-29 ...
#   ⚠ Нет данных погоды для 2024-08-29
# Обрабатываем 2024-08-30 ...
#   ⚠ Нет данных погоды для 2024-08-30
# Обрабатываем 2024-08-31 ...
#   ⚠ Нет данных погоды для 2024-08-31
# Обрабатываем 2024-09-01 ...
#   ⚠ Нет данных погоды для 2024-09-01
# Обрабатываем 2024-09-02 ...
#   ⚠ Нет данных погоды для 2024-09-02
# Обрабатываем 2024-09-03 ...
#   ⚠ Нет данных погоды для 2024-09-03
# Обрабатываем 2024-09-04 ...
#   ⚠ Нет данных погоды для 2024-09-04
# Обрабатываем 2024-09-05 ...
#   ⚠ Нет данных погоды для 2024-09-05
# Обрабатываем 2024-09-06 ...
#   ⚠ Нет данных погоды для 2024-09-06
# Обрабатываем 2024-09-07 ...
#   ⚠ Нет данных погоды для 2024-09-07
# Обрабатываем 2024-09-08 ...
#   ⚠ Нет данных погоды для 2024-09-08
# Обрабатываем 2024-09-09 ...
#   ⚠ Нет данных погоды для 2024-09-09
# Обрабатываем 2024-09-10 ...
#   ⚠ Нет данных погоды для 2024-09-10
# Обрабатываем 2024-09-11 ...
#   ⚠ Нет данных погоды для 2024-09-11
# Обрабатываем 2024-09-12 ...
#   ⚠ Нет данных погоды для 2024-09-12
# Обрабатываем 2024-09-13 ...
#   ⚠ Нет данных погоды для 2024-09-13
# Обрабатываем 2024-09-14 ...
#   ⚠ Нет данных погоды для 2024-09-14
# Обрабатываем 2024-09-15 ...
#   ⚠ Нет данных погоды для 2024-09-15
# Обрабатываем 2024-09-16 ...
#   ⚠ Нет данных погоды для 2024-09-16
# Обрабатываем 2024-09-17 ...
#   ⚠ Нет данных погоды для 2024-09-17
# Обрабатываем 2024-09-18 ...
#   ⚠ Нет данных погоды для 2024-09-18
# Обрабатываем 2024-09-19 ...
#   ⚠ Нет данных погоды для 2024-09-19
# Обрабатываем 2024-09-20 ...
#   ⚠ Нет данных погоды для 2024-09-20
# Обрабатываем 2024-09-21 ...
#   ⚠ Нет данных погоды для 2024-09-21
# Обрабатываем 2024-09-22 ...
#   ⚠ Нет данных погоды для 2024-09-22
# Обрабатываем 2024-09-23 ...
#   ⚠ Нет данных погоды для 2024-09-23
# Обрабатываем 2024-09-24 ...
#   ⚠ Нет данных погоды для 2024-09-24
# Обрабатываем 2024-09-25 ...
#   ⚠ Нет данных погоды для 2024-09-25
# Обрабатываем 2024-09-26 ...
#   ⚠ Нет данных погоды для 2024-09-26
# Обрабатываем 2024-09-27 ...
#   ⚠ Нет данных погоды для 2024-09-27
# Обрабатываем 2024-09-28 ...
#   ⚠ Нет данных погоды для 2024-09-28
# Обрабатываем 2024-09-29 ...
#   ⚠ Нет данных погоды для 2024-09-29
# Обрабатываем 2024-09-30 ...
#   ⚠ Нет данных погоды для 2024-09-30
# Обрабатываем 2024-10-01 ...
#   ⚠ Нет данных погоды для 2024-10-01
# Обрабатываем 2024-10-02 ...
#   ⚠ Нет данных погоды для 2024-10-02
# Обрабатываем 2024-10-03 ...
#   ⚠ Нет данных погоды для 2024-10-03
# Обрабатываем 2024-10-04 ...
#   ⚠ Нет данных погоды для 2024-10-04
# Обрабатываем 2024-10-05 ...
#   ⚠ Нет данных погоды для 2024-10-05
# Обрабатываем 2024-10-06 ...
#   ⚠ Нет данных погоды для 2024-10-06
# Обрабатываем 2024-10-07 ...
#   ⚠ Нет данных погоды для 2024-10-07
# Обрабатываем 2024-10-08 ...
#   ⚠ Нет данных погоды для 2024-10-08
# Обрабатываем 2024-10-09 ...
#   ⚠ Нет данных погоды для 2024-10-09
# Обрабатываем 2024-10-10 ...
#   ⚠ Нет данных погоды для 2024-10-10
# Обрабатываем 2024-10-11 ...
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-12
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-13
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-14
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-15
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-16
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-17
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-18
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-19
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-20
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-21
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-22
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-23
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-24
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-25
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-26
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-27
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-28
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-29
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-30
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-10-31
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-01
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-02
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-03
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-04
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-05
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-06
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-07
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-08
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-09
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-10
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-11
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-12
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-13
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-14
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-15
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-16
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-17
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-18
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-19
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-20
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-21
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-22
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-23
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-24
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-25
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-26
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-27
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-28
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-29
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-11-30
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-01
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-02
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-03
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-04
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-05
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-06
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-07
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-08
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-09
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-10
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-11
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-12
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-13
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-14
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-15
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-16
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-17
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-18
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-19
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-20
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-21
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-22
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-23
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-24
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-25
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-26
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-27
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-28
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-29
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-30
# ERROR:__main__:Няма записи за user_object_id=70 на 2024-12-31
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-01
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-02
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-03
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-04
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-05
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-06
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-07
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-08
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-09
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-10
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-11
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-12
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-13
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-14
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-15
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-16
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-17
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-18
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-19
#   ⚠ Нет данных погоды для 2024-10-11
# Обрабатываем 2024-10-12 ...
#   ⚠ Нет данных погоды для 2024-10-12
# Обрабатываем 2024-10-13 ...
#   ⚠ Нет данных погоды для 2024-10-13
# Обрабатываем 2024-10-14 ...
#   ⚠ Нет данных погоды для 2024-10-14
# Обрабатываем 2024-10-15 ...
#   ⚠ Нет данных погоды для 2024-10-15
# Обрабатываем 2024-10-16 ...
#   ⚠ Нет данных погоды для 2024-10-16
# Обрабатываем 2024-10-17 ...
#   ⚠ Нет данных погоды для 2024-10-17
# Обрабатываем 2024-10-18 ...
#   ⚠ Нет данных погоды для 2024-10-18
# Обрабатываем 2024-10-19 ...
#   ⚠ Нет данных погоды для 2024-10-19
# Обрабатываем 2024-10-20 ...
#   ⚠ Нет данных погоды для 2024-10-20
# Обрабатываем 2024-10-21 ...
#   ⚠ Нет данных погоды для 2024-10-21
# Обрабатываем 2024-10-22 ...
#   ⚠ Нет данных погоды для 2024-10-22
# Обрабатываем 2024-10-23 ...
#   ⚠ Нет данных погоды для 2024-10-23
# Обрабатываем 2024-10-24 ...
#   ⚠ Нет данных погоды для 2024-10-24
# Обрабатываем 2024-10-25 ...
#   ⚠ Нет данных погоды для 2024-10-25
# Обрабатываем 2024-10-26 ...
#   ⚠ Нет данных погоды для 2024-10-26
# Обрабатываем 2024-10-27 ...
#   ⚠ Нет данных погоды для 2024-10-27
# Обрабатываем 2024-10-28 ...
#   ⚠ Нет данных погоды для 2024-10-28
# Обрабатываем 2024-10-29 ...
#   ⚠ Нет данных погоды для 2024-10-29
# Обрабатываем 2024-10-30 ...
#   ⚠ Нет данных погоды для 2024-10-30
# Обрабатываем 2024-10-31 ...
#   ⚠ Нет данных погоды для 2024-10-31
# Обрабатываем 2024-11-01 ...
#   ⚠ Нет данных погоды для 2024-11-01
# Обрабатываем 2024-11-02 ...
#   ⚠ Нет данных погоды для 2024-11-02
# Обрабатываем 2024-11-03 ...
#   ⚠ Нет данных погоды для 2024-11-03
# Обрабатываем 2024-11-04 ...
#   ⚠ Нет данных погоды для 2024-11-04
# Обрабатываем 2024-11-05 ...
#   ⚠ Нет данных погоды для 2024-11-05
# Обрабатываем 2024-11-06 ...
#   ⚠ Нет данных погоды для 2024-11-06
# Обрабатываем 2024-11-07 ...
#   ⚠ Нет данных погоды для 2024-11-07
# Обрабатываем 2024-11-08 ...
#   ⚠ Нет данных погоды для 2024-11-08
# Обрабатываем 2024-11-09 ...
#   ⚠ Нет данных погоды для 2024-11-09
# Обрабатываем 2024-11-10 ...
#   ⚠ Нет данных погоды для 2024-11-10
# Обрабатываем 2024-11-11 ...
#   ⚠ Нет данных погоды для 2024-11-11
# Обрабатываем 2024-11-12 ...
#   ⚠ Нет данных погоды для 2024-11-12
# Обрабатываем 2024-11-13 ...
#   ⚠ Нет данных погоды для 2024-11-13
# Обрабатываем 2024-11-14 ...
#   ⚠ Нет данных погоды для 2024-11-14
# Обрабатываем 2024-11-15 ...
#   ⚠ Нет данных погоды для 2024-11-15
# Обрабатываем 2024-11-16 ...
#   ⚠ Нет данных погоды для 2024-11-16
# Обрабатываем 2024-11-17 ...
#   ⚠ Нет данных погоды для 2024-11-17
# Обрабатываем 2024-11-18 ...
#   ⚠ Нет данных погоды для 2024-11-18
# Обрабатываем 2024-11-19 ...
#   ⚠ Нет данных погоды для 2024-11-19
# Обрабатываем 2024-11-20 ...
#   ⚠ Нет данных погоды для 2024-11-20
# Обрабатываем 2024-11-21 ...
#   ⚠ Нет данных погоды для 2024-11-21
# Обрабатываем 2024-11-22 ...
#   ⚠ Нет данных погоды для 2024-11-22
# Обрабатываем 2024-11-23 ...
#   ⚠ Нет данных погоды для 2024-11-23
# Обрабатываем 2024-11-24 ...
#   ⚠ Нет данных погоды для 2024-11-24
# Обрабатываем 2024-11-25 ...
#   ⚠ Нет данных погоды для 2024-11-25
# Обрабатываем 2024-11-26 ...
#   ⚠ Нет данных погоды для 2024-11-26
# Обрабатываем 2024-11-27 ...
#   ⚠ Нет данных погоды для 2024-11-27
# Обрабатываем 2024-11-28 ...
#   ⚠ Нет данных погоды для 2024-11-28
# Обрабатываем 2024-11-29 ...
#   ⚠ Нет данных погоды для 2024-11-29
# Обрабатываем 2024-11-30 ...
#   ⚠ Нет данных погоды для 2024-11-30
# Обрабатываем 2024-12-01 ...
#   ⚠ Нет данных погоды для 2024-12-01
# Обрабатываем 2024-12-02 ...
#   ⚠ Нет данных погоды для 2024-12-02
# Обрабатываем 2024-12-03 ...
#   ⚠ Нет данных погоды для 2024-12-03
# Обрабатываем 2024-12-04 ...
#   ⚠ Нет данных погоды для 2024-12-04
# Обрабатываем 2024-12-05 ...
#   ⚠ Нет данных погоды для 2024-12-05
# Обрабатываем 2024-12-06 ...
#   ⚠ Нет данных погоды для 2024-12-06
# Обрабатываем 2024-12-07 ...
#   ⚠ Нет данных погоды для 2024-12-07
# Обрабатываем 2024-12-08 ...
#   ⚠ Нет данных погоды для 2024-12-08
# Обрабатываем 2024-12-09 ...
#   ⚠ Нет данных погоды для 2024-12-09
# Обрабатываем 2024-12-10 ...
#   ⚠ Нет данных погоды для 2024-12-10
# Обрабатываем 2024-12-11 ...
#   ⚠ Нет данных погоды для 2024-12-11
# Обрабатываем 2024-12-12 ...
#   ⚠ Нет данных погоды для 2024-12-12
# Обрабатываем 2024-12-13 ...
#   ⚠ Нет данных погоды для 2024-12-13
# Обрабатываем 2024-12-14 ...
#   ⚠ Нет данных погоды для 2024-12-14
# Обрабатываем 2024-12-15 ...
#   ⚠ Нет данных погоды для 2024-12-15
# Обрабатываем 2024-12-16 ...
#   ⚠ Нет данных погоды для 2024-12-16
# Обрабатываем 2024-12-17 ...
#   ⚠ Нет данных погоды для 2024-12-17
# Обрабатываем 2024-12-18 ...
#   ⚠ Нет данных погоды для 2024-12-18
# Обрабатываем 2024-12-19 ...
#   ⚠ Нет данных погоды для 2024-12-19
# Обрабатываем 2024-12-20 ...
#   ⚠ Нет данных погоды для 2024-12-20
# Обрабатываем 2024-12-21 ...
#   ⚠ Нет данных погоды для 2024-12-21
# Обрабатываем 2024-12-22 ...
#   ⚠ Нет данных погоды для 2024-12-22
# Обрабатываем 2024-12-23 ...
#   ⚠ Нет данных погоды для 2024-12-23
# Обрабатываем 2024-12-24 ...
#   ⚠ Нет данных погоды для 2024-12-24
# Обрабатываем 2024-12-25 ...
#   ⚠ Нет данных погоды для 2024-12-25
# Обрабатываем 2024-12-26 ...
#   ⚠ Нет данных погоды для 2024-12-26
# Обрабатываем 2024-12-27 ...
#   ⚠ Нет данных погоды для 2024-12-27
# Обрабатываем 2024-12-28 ...
#   ⚠ Нет данных погоды для 2024-12-28
# Обрабатываем 2024-12-29 ...
#   ⚠ Нет данных погоды для 2024-12-29
# Обрабатываем 2024-12-30 ...
#   ⚠ Нет данных погоды для 2024-12-30
# Обрабатываем 2024-12-31 ...
#   ⚠ Нет данных погоды для 2024-12-31
# Обрабатываем 2025-01-01 ...
#   ⚠ Нет данных погоды для 2025-01-01
# Обрабатываем 2025-01-02 ...
#   ⚠ Нет данных погоды для 2025-01-02
# Обрабатываем 2025-01-03 ...
#   ⚠ Нет данных погоды для 2025-01-03
# Обрабатываем 2025-01-04 ...
#   ⚠ Нет данных погоды для 2025-01-04
# Обрабатываем 2025-01-05 ...
#   ⚠ Нет данных погоды для 2025-01-05
# Обрабатываем 2025-01-06 ...
#   ⚠ Нет данных погоды для 2025-01-06
# Обрабатываем 2025-01-07 ...
#   ⚠ Нет данных погоды для 2025-01-07
# Обрабатываем 2025-01-08 ...
#   ⚠ Нет данных погоды для 2025-01-08
# Обрабатываем 2025-01-09 ...
#   ⚠ Нет данных погоды для 2025-01-09
# Обрабатываем 2025-01-10 ...
#   ⚠ Нет данных погоды для 2025-01-10
# Обрабатываем 2025-01-11 ...
#   ⚠ Нет данных погоды для 2025-01-11
# Обрабатываем 2025-01-12 ...
#   ⚠ Нет данных погоды для 2025-01-12
# Обрабатываем 2025-01-13 ...
#   ⚠ Нет данных погоды для 2025-01-13
# Обрабатываем 2025-01-14 ...
#   ⚠ Нет данных погоды для 2025-01-14
# Обрабатываем 2025-01-15 ...
#   ⚠ Нет данных погоды для 2025-01-15
# Обрабатываем 2025-01-16 ...
#   ⚠ Нет данных погоды для 2025-01-16
# Обрабатываем 2025-01-17 ...
#   ⚠ Нет данных погоды для 2025-01-17
# Обрабатываем 2025-01-18 ...
#   ⚠ Нет данных погоды для 2025-01-18
# Обрабатываем 2025-01-19 ...
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-20
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-21
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-22
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-23
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-24
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-25
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-26
# ERROR:__main__:Няма записи за user_object_id=70 на 2025-01-27
#   ⚠ Нет данных погоды для 2025-01-19
# Обрабатываем 2025-01-20 ...
#   ⚠ Нет данных погоды для 2025-01-20
# Обрабатываем 2025-01-21 ...
#   ⚠ Нет данных погоды для 2025-01-21
# Обрабатываем 2025-01-22 ...
#   ⚠ Нет данных погоды для 2025-01-22
# Обрабатываем 2025-01-23 ...
#   ⚠ Нет данных погоды для 2025-01-23
# Обрабатываем 2025-01-24 ...
#   ⚠ Нет данных погоды для 2025-01-24
# Обрабатываем 2025-01-25 ...
#   ⚠ Нет данных погоды для 2025-01-25
# Обрабатываем 2025-01-26 ...
#   ⚠ Нет данных погоды для 2025-01-26
# Обрабатываем 2025-01-27 ...
#   ⚠ Нет данных погоды для 2025-01-27
# Обрабатываем 2025-01-28 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      14 prediction_date = dt.strftime("%Y-%m-%d")
#      15 print(f"Обрабатываем {prediction_date} ...")
# ---> 17 df_weather = extract_weather_from_db(user_object_id, prediction_date)
#      19 if df_weather is None or df_weather.empty:
#      20     print(f"  ⚠ Нет данных погоды для {prediction_date}")
#
# Cell In[2], line 26, in extract_weather_from_db(user_object_id, prediction_date)
#      23     logger.error("Няма записи за user_object_id=%s на %s", user_object_id, prediction_date)
#      24     return None
# ---> 26 root_obj = deserialize_java_object(row[0])
#      27 if root_obj is None:
#      28     return None
#
# NameError: name 'deserialize_java_object' is not defined

# %%
import os
import logging
import pandas as pd
from sqlalchemy import create_engine, text
import javaobj  # javaobj-py3

logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)

# --- Параметры подключения к БД ---
DB_URI = "postgresql://postgres:smartgrid@172.31.168.2/solar_db"
engine = create_engine(DB_URI)

# Папка для сохранения CSV
OUTPUT_DIR = "data"
os.makedirs(OUTPUT_DIR, exist_ok=True)


def deserialize_java_object(binary_value):
    """
    Десериализация бинарного поля (bytea) в Java-объект через javaobj.loads.
    """
    if binary_value is None:
        return None
    if isinstance(binary_value, memoryview):
        binary_value = binary_value.tobytes()
    try:
        return javaobj.loads(binary_value)
    except Exception as e:
        logger.error("Грешка при десериализация на Java обект: %s", e)
        return None


def unwrap_value(obj):
    """
    Если obj имеет атрибут .value (JavaDouble/JavaInteger/JavaString) — вернуть obj.value,
    иначе вернуть obj как есть.
    """
    return getattr(obj, "value", obj)


def extract_forecast_data(forecast_obj):
    """
    Извлекает из forecast_obj список записей:
      - time   (строка "YYYY-MM-DD HH:MM")
      - temp_c (float)
      - cloud  (int)
    """
    days = getattr(forecast_obj, "forecastday", None)
    if days is None:
        return []
    try:
        days = list(days)
    except Exception as e:
        logger.error("Неуспешно преобразуване на forecastday в списък: %s", e)
        return []

    data = []
    for day in days:
        hours = getattr(day, "hour", None)
        if hours is None:
            continue
        try:
            hours = list(hours)
        except Exception as e:
            logger.error("Неуспешно преобразуване на hour в списък: %s", e)
            continue

        for hour in hours:
            t_raw     = getattr(hour, "time", None)
            temp_raw  = getattr(hour, "tempC", None)
            cloud_raw = getattr(hour, "cloud", None)

            t_str     = unwrap_value(t_raw)
            temp_val  = unwrap_value(temp_raw)
            cloud_val = unwrap_value(cloud_raw)

            try:
                temp_c = float(temp_val) if temp_val is not None else None
            except Exception:
                temp_c = None
            try:
                cloud = int(cloud_val) if cloud_val is not None else None
            except Exception:
                cloud = None

            if t_str:
                data.append({
                    "time": str(t_str),
                    "temp_c": temp_c,
                    "cloud": cloud
                })

    return data


def extract_weather_from_db(user_object_id, prediction_date):
    """
    1) SELECT current_data FROM weather_data
    2) десериализация Java-объекта
    3) извлечение forecast → extract_forecast_data
    4) DataFrame, to_datetime, ресемплинг 15 минут, интерполяция
    Возвращает DataFrame с колонками: time, temp_c, cloud
    """
    sql = text("""
        SELECT current_data
        FROM weather_data
        WHERE user_object_id = :uid
          AND date = :dt
        ORDER BY id
        LIMIT 1
    """)

    with engine.connect() as conn:
        row = conn.execute(sql, {"uid": user_object_id, "dt": prediction_date}).fetchone()

    if not row:
        logger.error("Няма записи за user_object_id=%s на %s", user_object_id, prediction_date)
        return None

    root_obj = deserialize_java_object(row[0])
    if root_obj is None:
        return None

    forecast_obj = getattr(root_obj, "forecast", None)
    if forecast_obj is None:
        logger.error("В десериализирания обект няма атрибут forecast")
        return None

    raw = extract_forecast_data(forecast_obj)
    if not raw:
        logger.error("extract_forecast_data върна празен списък")
        return None

    df = pd.DataFrame(raw)

    try:
        df["time"] = pd.to_datetime(df["time"], format="%Y-%m-%d %H:%M")
    except Exception as e:
        logger.error("Неуспешна конверсия на време: %s", e)
        return None

    df = df.drop_duplicates(subset="time").set_index("time").sort_index()

    for col in ["temp_c", "cloud"]:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    if df[["temp_c", "cloud"]].isna().all().all():
        logger.error("Няма валидни числа в temp_c или cloud за интерполация")
        return None

    try:
        df15 = df.resample("15min").interpolate(method="linear")
    except Exception as e:
        logger.error("Грешка при ресемплиране: %s", e)
        return None

    df15 = df15.reset_index()
    df15["time"] = df15["time"].dt.strftime("%Y-%m-%d %H:%M")
    return df15

# %%
user_object_id = 70

sql_dates = text("""
    SELECT DISTINCT date
    FROM weather_data
    WHERE user_object_id = :uid
    ORDER BY date
""")

with engine.connect() as conn:
    df_dates = pd.read_sql(sql_dates, conn, params={"uid": user_object_id})

df_dates
# Out:
#            date
# 0    2025-01-28
# 1    2025-01-29
# 2    2025-01-30
# 3    2025-01-31
# 4    2025-02-01
# ..          ...
# 290  2025-11-14
# 291  2025-11-15
# 292  2025-11-16
# 293  2025-11-17
# 294  2025-11-18
#
# [295 rows x 1 columns]

# %%
user_object_id = 70

# df_dates уже получен в предыдущей ячейке
available_dates = pd.to_datetime(df_dates["date"]).dt.strftime("%Y-%m-%d").tolist()
print("Найдено дат с погодой:", len(available_dates))
print("Первые 10:", available_dates[:10])

for prediction_date in available_dates:
    print(f"Обрабатываем {prediction_date} ...")

    df_weather = extract_weather_from_db(user_object_id, prediction_date)

    if df_weather is None or df_weather.empty:
        print(f"  ⚠ Нет данных погоды (после десериализации) для {prediction_date}")
        continue

    filename = f"weather_uid_{user_object_id}_{prediction_date}.csv"
    out_path = os.path.join(OUTPUT_DIR, filename)

    df_weather.to_csv(out_path, index=False, encoding="utf-8")
    print(f"  ✅ Успешно записано: {out_path}")

print("Готово!")
# Out:
# Найдено дат с погодой: 295
# Первые 10: ['2025-01-28', '2025-01-29', '2025-01-30', '2025-01-31', '2025-02-01', '2025-02-02', '2025-02-03', '2025-02-04', '2025-02-05', '2025-02-06']
# Обрабатываем 2025-01-28 ...
#   ⚠ Нет данных погоды (после десериализации) для 2025-01-28
# Обрабатываем 2025-01-29 ...
#   ⚠ Нет данных погоды (после десериализации) для 2025-01-29
# Обрабатываем 2025-01-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-01-30.csv
# Обрабатываем 2025-01-31 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-01-31.csv
# Обрабатываем 2025-02-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-01.csv
# Обрабатываем 2025-02-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-02.csv
# Обрабатываем 2025-02-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-03.csv
# Обрабатываем 2025-02-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-04.csv
# Обрабатываем 2025-02-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-05.csv
# Обрабатываем 2025-02-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-06.csv
# Обрабатываем 2025-02-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-07.csv
# Обрабатываем 2025-02-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-08.csv
# Обрабатываем 2025-02-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-09.csv
# Обрабатываем 2025-02-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-10.csv
# Обрабатываем 2025-02-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-11.csv
# Обрабатываем 2025-02-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-12.csv
# Обрабатываем 2025-02-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-13.csv
# Обрабатываем 2025-02-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-14.csv
# Обрабатываем 2025-02-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-15.csv
# Обрабатываем 2025-02-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-16.csv
# Обрабатываем 2025-02-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-17.csv
# Обрабатываем 2025-02-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-18.csv
# Обрабатываем 2025-02-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-19.csv
# Обрабатываем 2025-02-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-20.csv
# Обрабатываем 2025-02-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-21.csv
# Обрабатываем 2025-02-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-22.csv
# Обрабатываем 2025-02-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-23.csv
# Обрабатываем 2025-02-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-24.csv
# Обрабатываем 2025-02-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-25.csv
# Обрабатываем 2025-02-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-26.csv
# Обрабатываем 2025-02-27 ...
#   ⚠ Нет данных погоды (после десериализации) для 2025-02-27
# Обрабатываем 2025-02-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-02-28.csv
# Обрабатываем 2025-03-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-01.csv
# Обрабатываем 2025-03-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-02.csv
# Обрабатываем 2025-03-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-03.csv
# Обрабатываем 2025-03-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-04.csv
# Обрабатываем 2025-03-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-05.csv
# Обрабатываем 2025-03-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-06.csv
# Обрабатываем 2025-03-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-07.csv
# Обрабатываем 2025-03-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-08.csv
# Обрабатываем 2025-03-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-09.csv
# Обрабатываем 2025-03-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-10.csv
# Обрабатываем 2025-03-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-11.csv
# Обрабатываем 2025-03-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-12.csv
# Обрабатываем 2025-03-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-13.csv
# Обрабатываем 2025-03-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-14.csv
# Обрабатываем 2025-03-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-15.csv
# Обрабатываем 2025-03-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-16.csv
# Обрабатываем 2025-03-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-17.csv
# Обрабатываем 2025-03-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-18.csv
# Обрабатываем 2025-03-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-19.csv
# Обрабатываем 2025-03-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-20.csv
# Обрабатываем 2025-03-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-21.csv
# Обрабатываем 2025-03-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-22.csv
# Обрабатываем 2025-03-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-23.csv
# Обрабатываем 2025-03-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-24.csv
# Обрабатываем 2025-03-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-25.csv
# Обрабатываем 2025-03-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-26.csv
# Обрабатываем 2025-03-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-27.csv
# Обрабатываем 2025-03-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-28.csv
# Обрабатываем 2025-03-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-29.csv
# Обрабатываем 2025-03-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-30.csv
# Обрабатываем 2025-03-31 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-03-31.csv
# Обрабатываем 2025-04-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-01.csv
# Обрабатываем 2025-04-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-02.csv
# Обрабатываем 2025-04-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-03.csv
# Обрабатываем 2025-04-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-04.csv
# Обрабатываем 2025-04-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-05.csv
# Обрабатываем 2025-04-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-06.csv
# Обрабатываем 2025-04-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-07.csv
# Обрабатываем 2025-04-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-08.csv
# Обрабатываем 2025-04-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-09.csv
# Обрабатываем 2025-04-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-10.csv
# Обрабатываем 2025-04-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-11.csv
# Обрабатываем 2025-04-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-12.csv
# Обрабатываем 2025-04-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-13.csv
# Обрабатываем 2025-04-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-14.csv
# Обрабатываем 2025-04-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-15.csv
# Обрабатываем 2025-04-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-16.csv
# Обрабатываем 2025-04-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-17.csv
# Обрабатываем 2025-04-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-18.csv
# Обрабатываем 2025-04-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-19.csv
# Обрабатываем 2025-04-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-20.csv
# Обрабатываем 2025-04-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-21.csv
# Обрабатываем 2025-04-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-22.csv
# Обрабатываем 2025-04-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-23.csv
# Обрабатываем 2025-04-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-24.csv
# Обрабатываем 2025-04-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-25.csv
# Обрабатываем 2025-04-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-26.csv
# Обрабатываем 2025-04-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-27.csv
# Обрабатываем 2025-04-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-28.csv
# Обрабатываем 2025-04-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-29.csv
# Обрабатываем 2025-04-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-04-30.csv
# Обрабатываем 2025-05-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-01.csv
# Обрабатываем 2025-05-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-02.csv
# Обрабатываем 2025-05-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-03.csv
# Обрабатываем 2025-05-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-04.csv
# Обрабатываем 2025-05-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-05.csv
# Обрабатываем 2025-05-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-06.csv
# Обрабатываем 2025-05-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-07.csv
# Обрабатываем 2025-05-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-08.csv
# Обрабатываем 2025-05-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-09.csv
# Обрабатываем 2025-05-10 ...
#   ⚠ Нет данных погоды (после десериализации) для 2025-05-10
# Обрабатываем 2025-05-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-11.csv
# Обрабатываем 2025-05-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-12.csv
# Обрабатываем 2025-05-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-13.csv
# Обрабатываем 2025-05-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-14.csv
# Обрабатываем 2025-05-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-15.csv
# Обрабатываем 2025-05-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-16.csv
# Обрабатываем 2025-05-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-17.csv
# Обрабатываем 2025-05-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-18.csv
# Обрабатываем 2025-05-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-19.csv
# Обрабатываем 2025-05-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-20.csv
# Обрабатываем 2025-05-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-21.csv
# Обрабатываем 2025-05-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-22.csv
# Обрабатываем 2025-05-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-23.csv
# Обрабатываем 2025-05-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-24.csv
# Обрабатываем 2025-05-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-25.csv
# Обрабатываем 2025-05-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-26.csv
# Обрабатываем 2025-05-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-27.csv
# Обрабатываем 2025-05-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-28.csv
# Обрабатываем 2025-05-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-29.csv
# Обрабатываем 2025-05-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-30.csv
# Обрабатываем 2025-05-31 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-05-31.csv
# Обрабатываем 2025-06-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-01.csv
# Обрабатываем 2025-06-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-02.csv
# Обрабатываем 2025-06-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-03.csv
# Обрабатываем 2025-06-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-04.csv
# Обрабатываем 2025-06-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-05.csv
# Обрабатываем 2025-06-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-06.csv
# Обрабатываем 2025-06-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-07.csv
# Обрабатываем 2025-06-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-08.csv
# Обрабатываем 2025-06-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-09.csv
# Обрабатываем 2025-06-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-10.csv
# Обрабатываем 2025-06-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-11.csv
# Обрабатываем 2025-06-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-12.csv
# Обрабатываем 2025-06-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-13.csv
# Обрабатываем 2025-06-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-14.csv
# Обрабатываем 2025-06-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-15.csv
# Обрабатываем 2025-06-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-16.csv
# Обрабатываем 2025-06-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-17.csv
# Обрабатываем 2025-06-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-18.csv
# Обрабатываем 2025-06-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-19.csv
# Обрабатываем 2025-06-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-20.csv
# Обрабатываем 2025-06-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-21.csv
# Обрабатываем 2025-06-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-22.csv
# Обрабатываем 2025-06-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-23.csv
# Обрабатываем 2025-06-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-24.csv
# Обрабатываем 2025-06-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-25.csv
# Обрабатываем 2025-06-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-26.csv
# Обрабатываем 2025-06-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-27.csv
# Обрабатываем 2025-06-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-28.csv
# Обрабатываем 2025-06-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-29.csv
# Обрабатываем 2025-06-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-06-30.csv
# Обрабатываем 2025-07-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-01.csv
# Обрабатываем 2025-07-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-02.csv
# Обрабатываем 2025-07-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-03.csv
# Обрабатываем 2025-07-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-04.csv
# Обрабатываем 2025-07-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-05.csv
# Обрабатываем 2025-07-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-06.csv
# Обрабатываем 2025-07-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-07.csv
# Обрабатываем 2025-07-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-08.csv
# Обрабатываем 2025-07-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-09.csv
# Обрабатываем 2025-07-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-10.csv
# Обрабатываем 2025-07-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-11.csv
# Обрабатываем 2025-07-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-12.csv
# Обрабатываем 2025-07-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-13.csv
# Обрабатываем 2025-07-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-14.csv
# Обрабатываем 2025-07-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-15.csv
# Обрабатываем 2025-07-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-16.csv
# Обрабатываем 2025-07-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-17.csv
# Обрабатываем 2025-07-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-18.csv
# Обрабатываем 2025-07-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-19.csv
# Обрабатываем 2025-07-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-20.csv
# Обрабатываем 2025-07-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-21.csv
# Обрабатываем 2025-07-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-22.csv
# Обрабатываем 2025-07-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-23.csv
# Обрабатываем 2025-07-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-24.csv
# Обрабатываем 2025-07-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-25.csv
# Обрабатываем 2025-07-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-26.csv
# Обрабатываем 2025-07-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-27.csv
# Обрабатываем 2025-07-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-28.csv
# Обрабатываем 2025-07-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-29.csv
# Обрабатываем 2025-07-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-30.csv
# Обрабатываем 2025-07-31 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-07-31.csv
# Обрабатываем 2025-08-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-01.csv
# Обрабатываем 2025-08-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-02.csv
# Обрабатываем 2025-08-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-03.csv
# Обрабатываем 2025-08-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-04.csv
# Обрабатываем 2025-08-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-05.csv
# Обрабатываем 2025-08-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-06.csv
# Обрабатываем 2025-08-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-07.csv
# Обрабатываем 2025-08-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-08.csv
# Обрабатываем 2025-08-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-09.csv
# Обрабатываем 2025-08-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-10.csv
# Обрабатываем 2025-08-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-11.csv
# Обрабатываем 2025-08-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-12.csv
# Обрабатываем 2025-08-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-13.csv
# Обрабатываем 2025-08-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-14.csv
# Обрабатываем 2025-08-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-15.csv
# Обрабатываем 2025-08-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-16.csv
# Обрабатываем 2025-08-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-17.csv
# Обрабатываем 2025-08-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-18.csv
# Обрабатываем 2025-08-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-19.csv
# Обрабатываем 2025-08-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-20.csv
# Обрабатываем 2025-08-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-21.csv
# Обрабатываем 2025-08-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-22.csv
# Обрабатываем 2025-08-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-23.csv
# Обрабатываем 2025-08-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-24.csv
# Обрабатываем 2025-08-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-25.csv
# Обрабатываем 2025-08-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-26.csv
# Обрабатываем 2025-08-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-27.csv
# Обрабатываем 2025-08-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-28.csv
# Обрабатываем 2025-08-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-29.csv
# Обрабатываем 2025-08-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-30.csv
# Обрабатываем 2025-08-31 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-08-31.csv
# Обрабатываем 2025-09-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-01.csv
# Обрабатываем 2025-09-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-02.csv
# Обрабатываем 2025-09-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-03.csv
# Обрабатываем 2025-09-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-04.csv
# Обрабатываем 2025-09-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-05.csv
# Обрабатываем 2025-09-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-06.csv
# Обрабатываем 2025-09-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-07.csv
# Обрабатываем 2025-09-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-08.csv
# Обрабатываем 2025-09-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-09.csv
# Обрабатываем 2025-09-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-10.csv
# Обрабатываем 2025-09-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-11.csv
# Обрабатываем 2025-09-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-12.csv
# Обрабатываем 2025-09-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-13.csv
# Обрабатываем 2025-09-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-14.csv
# Обрабатываем 2025-09-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-15.csv
# Обрабатываем 2025-09-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-16.csv
# Обрабатываем 2025-09-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-17.csv
# Обрабатываем 2025-09-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-18.csv
# Обрабатываем 2025-09-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-19.csv
# Обрабатываем 2025-09-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-20.csv
# Обрабатываем 2025-09-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-21.csv
# Обрабатываем 2025-09-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-22.csv
# Обрабатываем 2025-09-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-23.csv
# Обрабатываем 2025-09-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-24.csv
# Обрабатываем 2025-09-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-25.csv
# Обрабатываем 2025-09-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-26.csv
# Обрабатываем 2025-09-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-27.csv
# Обрабатываем 2025-09-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-28.csv
# Обрабатываем 2025-09-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-29.csv
# Обрабатываем 2025-09-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-09-30.csv
# Обрабатываем 2025-10-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-01.csv
# Обрабатываем 2025-10-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-02.csv
# Обрабатываем 2025-10-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-03.csv
# Обрабатываем 2025-10-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-04.csv
# Обрабатываем 2025-10-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-05.csv
# Обрабатываем 2025-10-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-06.csv
# Обрабатываем 2025-10-07 ...
#   ⚠ Нет данных погоды (после десериализации) для 2025-10-07
# Обрабатываем 2025-10-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-08.csv
# Обрабатываем 2025-10-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-09.csv
# Обрабатываем 2025-10-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-10.csv
# Обрабатываем 2025-10-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-11.csv
# Обрабатываем 2025-10-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-12.csv
# Обрабатываем 2025-10-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-13.csv
# Обрабатываем 2025-10-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-14.csv
# Обрабатываем 2025-10-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-15.csv
# Обрабатываем 2025-10-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-16.csv
# Обрабатываем 2025-10-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-17.csv
# Обрабатываем 2025-10-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-18.csv
# Обрабатываем 2025-10-19 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-19.csv
# Обрабатываем 2025-10-20 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-20.csv
# Обрабатываем 2025-10-21 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-21.csv
# Обрабатываем 2025-10-22 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-22.csv
# Обрабатываем 2025-10-23 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-23.csv
# Обрабатываем 2025-10-24 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-24.csv
# Обрабатываем 2025-10-25 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-25.csv
# Обрабатываем 2025-10-26 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-26.csv
# Обрабатываем 2025-10-27 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-27.csv
# Обрабатываем 2025-10-28 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-28.csv
# Обрабатываем 2025-10-29 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-29.csv
# Обрабатываем 2025-10-30 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-30.csv
# Обрабатываем 2025-10-31 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-10-31.csv
# Обрабатываем 2025-11-01 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-01.csv
# Обрабатываем 2025-11-02 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-02.csv
# Обрабатываем 2025-11-03 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-03.csv
# Обрабатываем 2025-11-04 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-04.csv
# Обрабатываем 2025-11-05 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-05.csv
# Обрабатываем 2025-11-06 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-06.csv
# Обрабатываем 2025-11-07 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-07.csv
# Обрабатываем 2025-11-08 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-08.csv
# Обрабатываем 2025-11-09 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-09.csv
# Обрабатываем 2025-11-10 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-10.csv
# Обрабатываем 2025-11-11 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-11.csv
# Обрабатываем 2025-11-12 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-12.csv
# Обрабатываем 2025-11-13 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-13.csv
# Обрабатываем 2025-11-14 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-14.csv
# Обрабатываем 2025-11-15 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-15.csv
# Обрабатываем 2025-11-16 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-16.csv
# Обрабатываем 2025-11-17 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-17.csv
# Обрабатываем 2025-11-18 ...
#   ✅ Успешно записано: data\weather_uid_70_2025-11-18.csv
# Готово!
