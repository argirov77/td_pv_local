# %%
# Клетка 1: Подготовка на данните за обучение

import numpy as np
import pandas as pd

# Работим с копие, за да не пипаме оригиналния df
data = df.copy()

# 1) махаме нощните часове – там мощността е ~0 и само шум
data = data[data["power_kw"] > 0]

# 2) избираме колоните, които ще използваме като признаци
feature_cols = ["temp_c", "cloud", "hour", "dayofyear"]
target_col = "power_kw"

X = data[feature_cols].copy()
y = data[target_col].copy()

print("Форма на X:", X.shape)
print("Форма на y:", y.shape)
display(X.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 import pandas as pd
#       6 # Работим с копие, за да не пипаме оригиналния df
# ----> 7 data = df.copy()
#       9 # 1) махаме нощните часове – там мощността е ~0 и само шум
#      10 data = data[data["power_kw"] > 0]
#
# NameError: name 'df' is not defined
